# %%
from rdflib import Graph, Namespace
from rdflib.plugins.sparql import prepareQuery

# %%
# Load RDF data into a graph
rdf_file = "./estacion.ttl"  # Replace with the path to your TTL file
g = Graph()
g.parse(rdf_file, format="ttl")

# Define namespaces
NS = Namespace("https://www.dominiowebsemant.com/ontology/CercaniasMalaga#")
BASE = Namespace("http://websemantica/base#")

# %%
# Query 1: Retrieve all stations with their coordinates and descriptions
q1 = prepareQuery('''
  SELECT ?station ?code ?name ?latitude ?longitude
  WHERE {
    # ?station a ns:Estación ;
             ns:codigoEstacion ?code ;
             ns:nombreEstacion ?name ;
             ns:latitud ?latitude ;
             ns:longitud ?longitude .
  }
''', initNs={"ns": NS})

print("Query 1: Retrieve all stations with their coordinates and descriptions")
for r in g.query(q1):
    print(f"Station: {r.station}, Code: {r.code}, Name: {r.name}, Latitude: {r.latitude}, Longitude: {r.longitude}")
# Out:
# Query 1: Retrieve all stations with their coordinates and descriptions
# Station: http://websemantica/base#Estacion/54405, Code: 54405, Name: ALORA, Latitude: 36.819838, Longitude: -4.699623
# Station: http://websemantica/base#Estacion/54406, Code: 54406, Name: PIZARRA, Latitude: 36.765619, Longitude: -4.7111214
# Station: http://websemantica/base#Estacion/54407, Code: 54407, Name: ALJAIMA, Latitude: 36.733092, Longitude: -4.664725
# Station: http://websemantica/base#Estacion/54408, Code: 54408, Name: CARTAMA, Latitude: 36.7334013, Longitude: -4.6093394
# Station: http://websemantica/base#Estacion/54410, Code: 54410, Name: CAMPANILLAS, Latitude: 36.705011, Longitude: -4.545516
# Station: http://websemantica/base#Estacion/54412, Code: 54412, Name: LOS PRADOS, Latitude: 36.6988637, Longitude: -4.4778853
# Station: http://websemantica/base#Estacion/54413, Code: 54413, Name: MALAGA MARIA ZAMBRANO, Latitude: 36.7113412, Longitude: -4.4328779
# Station: http://websemantica/base#Estacion/54501, Code: 54501, Name: VICTORIA KENT, Latitude: 36.6962281, Longitude: -4.4652369
# Station: http://websemantica/base#Estacion/54503, Code: 54503, Name: GUADALHORCE, Latitude: 36.6921154, Longitude: -4.4831263
# Station: http://websemantica/base#Estacion/54505, Code: 54505, Name: AEROPUERTO, Latitude: 36.6760678, Longitude: -4.4879567
# Station: http://websemantica/base#Estacion/54508, Code: 54508, Name: LA COLINA, Latitude: 36.6401889, Longitude: -4.4952547
# Station: http://websemantica/base#Estacion/54509, Code: 54509, Name: TORREMOLINOS, Latitude: 36.6253108, Longitude: -4.4966871
# Station: http://websemantica/base#Estacion/54510, Code: 54510, Name: EL PINILLO, Latitude: 36.6101783, Longitude: -4.5146208
# Station: http://websemantica/base#Estacion/54511, Code: 54511, Name: BENALMADENA-ARROYO DE LA MIEL, Latitude: 36.599091, Longitude: -4.536341
# Station: http://websemantica/base#Estacion/54512, Code: 54512, Name: TORREMUELLE, Latitude: 36.5798535, Longitude: -4.573148
# Station: http://websemantica/base#Estacion/54513, Code: 54513, Name: CARVAJAL, Latitude: 36.570308, Longitude: -4.594023
# Station: http://websemantica/base#Estacion/54514, Code: 54514, Name: TORREBLANCA, Latitude: 36.5636, Longitude: -4.60966
# Station: http://websemantica/base#Estacion/54515, Code: 54515, Name: LOS BOLICHES, Latitude: 36.5515902, Longitude: -4.6166673
# Station: http://websemantica/base#Estacion/54516, Code: 54516, Name: FUENGIROLA, Latitude: 36.546263, Longitude: -4.6203322
# Station: http://websemantica/base#Estacion/54517, Code: 54517, Name: MALAGA-CENTRO ALAMEDA, Latitude: 36.71965, Longitude: -4.420019
# Station: http://websemantica/base#Estacion/54518, Code: 54518, Name: LOS ALAMOS, Latitude: 36.6452816, Longitude: -4.4848827
# Station: http://websemantica/base#Estacion/54519, Code: 54519, Name: MONTEMAR ALTO, Latitude: 36.6138194, Longitude: -4.5089797
# Station: http://websemantica/base#Estacion/54520, Code: 54520, Name: PLAZA MAYOR, Latitude: 36.6560328, Longitude: -4.4800137

# %%
# Query 2: List all nuclei and their associated stations
q2 = prepareQuery('''
  SELECT ?nucleo ?nucleoName ?station
  WHERE {
    # ?nucleo a ns:NucleoCercanias ;
            ns:nombreNucleo ?nucleoName .
    # ?station ns:tieneNucleo ?nucleo .
  }
''', initNs={"ns": NS})

print("\nQuery 2: List all nuclei and their associated stations")
for r in g.query(q2):
    print(f"Nucleus: {r.nucleo}, Name: {r.nucleoName}, Station: {r.station}")
# Out:
# Query 2: List all nuclei and their associated stations
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54405
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54406
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54407
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54408
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54410
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54412
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54413
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54501
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54503
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54505
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54508
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54509
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54510
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54511
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54512
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54513
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54514
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54515
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54516
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54517
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54518
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54519
# Nucleus: http://websemantica/base#Nucleo/M%C3%81LAGA, Name: MÁLAGA, Station: http://websemantica/base#Estacion/54520

# %%
# Query 3: Retrieve all stations and their associated addresses
q3 = prepareQuery('''
  SELECT ?station ?stationName ?address ?addressName
  WHERE {
    # ?station a ns:Estación ;
             ns:nombreEstacion ?stationName ;
             ns:localizadoEn ?address .
    # ?address ns:nombreDireccion ?addressName .
  }
''', initNs={"ns": NS})

print("\nQuery 3: Retrieve all stations and their associated addresses")
for r in g.query(q3):
    print(f"Station: {r.station}, Name: {r.stationName}, Address: {r.address}, Address Name: {r.addressName}")
# Out:
# Query 3: Retrieve all stations and their associated addresses
# Station: http://websemantica/base#Estacion/54405, Name: ALORA, Address: http://websemantica/base#Direccion/54405, Address Name: CALLE ESTACION FERROCARRIL
# Station: http://websemantica/base#Estacion/54406, Name: PIZARRA, Address: http://websemantica/base#Direccion/54406, Address Name: PLAZA ESTACION FERROCARRIL
# Station: http://websemantica/base#Estacion/54407, Name: ALJAIMA, Address: http://websemantica/base#Direccion/54407, Address Name: CARRETERA A-7054 - ESTACION FERROCARRIL
# Station: http://websemantica/base#Estacion/54408, Name: CARTAMA, Address: http://websemantica/base#Direccion/54408, Address Name: BARRIADA GARCIA AGUA
# Station: http://websemantica/base#Estacion/54410, Name: CAMPANILLAS, Address: http://websemantica/base#Direccion/54410, Address Name: CALLE ALMENCINO - ESTACION FERROCARRIL
# Station: http://websemantica/base#Estacion/54412, Name: LOS PRADOS, Address: http://websemantica/base#Direccion/54412, Address Name: CALLE CAMINO PRADOS
# Station: http://websemantica/base#Estacion/54413, Name: MALAGA MARIA ZAMBRANO, Address: http://websemantica/base#Direccion/54413, Address Name: CALLE EXPLANADA DE LA ESTACION
# Station: http://websemantica/base#Estacion/54501, Name: VICTORIA KENT, Address: http://websemantica/base#Direccion/54501, Address Name: PLATERO FRANCISCO VAZQUEZ
# Station: http://websemantica/base#Estacion/54503, Name: GUADALHORCE, Address: http://websemantica/base#Direccion/54503, Address Name: CALLE CESAR VALLEJO - ESTACION FERROCARRIL
# Station: http://websemantica/base#Estacion/54505, Name: AEROPUERTO, Address: http://websemantica/base#Direccion/54505, Address Name: AVENIDA COMANDANTE GARCIA MORATO
# Station: http://websemantica/base#Estacion/54508, Name: LA COLINA, Address: http://websemantica/base#Direccion/54508, Address Name: URBANIZACION LA COLINA
# Station: http://websemantica/base#Estacion/54509, Name: TORREMOLINOS, Address: http://websemantica/base#Direccion/54509, Address Name: PLAZA DE LA NOGALERA
# Station: http://websemantica/base#Estacion/54510, Name: EL PINILLO, Address: http://websemantica/base#Direccion/54510, Address Name: DECANOM JUAN DE HOYOS
# Station: http://websemantica/base#Estacion/54511, Name: BENALMADENA-ARROYO DE LA MIEL, Address: http://websemantica/base#Direccion/54511, Address Name: AVENIDA DE LA ESTACION
# Station: http://websemantica/base#Estacion/54512, Name: TORREMUELLE, Address: http://websemantica/base#Direccion/54512, Address Name: URBANIZACION TORREMUELLE
# Station: http://websemantica/base#Estacion/54513, Name: CARVAJAL, Address: http://websemantica/base#Direccion/54513, Address Name: CALLE SIERRA DE CAZORLA
# Station: http://websemantica/base#Estacion/54514, Name: TORREBLANCA, Address: http://websemantica/base#Direccion/54514, Address Name: CALLE PUEBLA BLANCA
# Station: http://websemantica/base#Estacion/54515, Name: LOS BOLICHES, Address: http://websemantica/base#Direccion/54515, Address Name: AVENIDA DE LOS BOLICHES
# Station: http://websemantica/base#Estacion/54516, Name: FUENGIROLA, Address: http://websemantica/base#Direccion/54516, Address Name: AVENIDA JESUS SANTOS REIN
# Station: http://websemantica/base#Estacion/54517, Name: MALAGA-CENTRO ALAMEDA, Address: http://websemantica/base#Direccion/54517, Address Name: AVENIDA AURORA
# Station: http://websemantica/base#Estacion/54518, Name: LOS ALAMOS, Address: http://websemantica/base#Direccion/54518, Address Name: CALLE MENTON
# Station: http://websemantica/base#Estacion/54519, Name: MONTEMAR ALTO, Address: http://websemantica/base#Direccion/54519, Address Name: JACINTO MESA
# Station: http://websemantica/base#Estacion/54520, Name: PLAZA MAYOR, Address: http://websemantica/base#Direccion/54520, Address Name: CALLE ALFONSO PONCE DE LEON

# %%
# Query 4: List all provinces and their populations
q4 = prepareQuery('''
  SELECT ?provincia ?poblacion
  WHERE {
    # ?provincia a ns:Provincia .
    # ?poblacion a ns:Poblacion .
    # ?provincia ns:tienePoblacion ?poblacion .
  }
''', initNs={"ns": NS})

print("\nQuery 4: List all provinces and their populations")
for row in g.query(q4):
    print(f"Provincia: {row.provincia}, Población: {row.poblacion}")
# Out:
# Query 4: List all provinces and their populations
# Provincia: http://websemantica/base#Provincia/%C3%81lora, Población: http://websemantica/base#Poblacion/%C3%81lora
# Provincia: http://websemantica/base#Provincia/Benalm%C3%A1dena, Población: http://websemantica/base#Poblacion/Benalm%C3%A1dena
# Provincia: http://websemantica/base#Provincia/C%C3%A1rtama, Población: http://websemantica/base#Poblacion/C%C3%A1rtama
# Provincia: http://websemantica/base#Provincia/Fuengirola, Población: http://websemantica/base#Poblacion/Fuengirola
# Provincia: http://websemantica/base#Provincia/M%C3%A1laga, Población: http://websemantica/base#Poblacion/M%C3%A1laga
# Provincia: http://websemantica/base#Provincia/Pizarra, Población: http://websemantica/base#Poblacion/Pizarra
# Provincia: http://websemantica/base#Provincia/Torremolinos, Población: http://websemantica/base#Poblacion/Torremolinos

# %%
# Query 5: Retrieve trip segments (tramos) with passenger data
q5 = prepareQuery('''
  SELECT ?segment ?interval ?station ?subidos ?bajados
  WHERE {
    # ?segment a ns:Tramo ;
    ns:intervalo ?interval ;
    ns:tieneEstacion ?station ;
    ns:viajerosSubidos ?subidos ;
    ns:viajerosBajados ?bajados .
  } LIMIT 10
''', initNs={"ns": NS})

print("\nQuery 5: Retrieve trip segments (tramos) with passenger data")
for row in g.query(q5):
    print(f"Segment: {row.segment}, Interval: {row.interval}, Station: {row.station}, Subidos: {row.subidos}, Bajados: {row.bajados}")
# Out:
# Query 5: Retrieve trip segments (tramos) with passenger data
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0000_0030, Interval: 00:00 - 00:30, Station: http://websemantica/base#Estacion/54505, Subidos: 6, Bajados: 3.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0030_0100, Interval: 00:30 - 01:00, Station: http://websemantica/base#Estacion/54505, Subidos: 5, Bajados: 2.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0530_0600, Interval: 05:30 - 06:00, Station: http://websemantica/base#Estacion/54505, Subidos: 4, Bajados: 22.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0600_0630, Interval: 06:00 - 06:30, Station: http://websemantica/base#Estacion/54505, Subidos: 0, Bajados: 22.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0630_0700, Interval: 06:30 - 07:00, Station: http://websemantica/base#Estacion/54505, Subidos: 15, Bajados: 38.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0700_0730, Interval: 07:00 - 07:30, Station: http://websemantica/base#Estacion/54505, Subidos: 4, Bajados: 50.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0730_0800, Interval: 07:30 - 08:00, Station: http://websemantica/base#Estacion/54505, Subidos: 6, Bajados: 73.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0800_0830, Interval: 08:00 - 08:30, Station: http://websemantica/base#Estacion/54505, Subidos: 13, Bajados: 84.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0830_0900, Interval: 08:30 - 09:00, Station: http://websemantica/base#Estacion/54505, Subidos: 45, Bajados: 80.0
# Segment: http://websemantica/base#Tramo/AEROPUERTO_0900_0930, Interval: 09:00 - 09:30, Station: http://websemantica/base#Estacion/54505, Subidos: 86, Bajados: 72.0
